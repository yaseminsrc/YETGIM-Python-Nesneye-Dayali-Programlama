# %%
print("Merhaba Dünya")

#Değişkenler

#int
int_val = 10
print("İnteger Değer",int_val)
print(type(int_val))

#float
float_val = 10.5
print("\nFloat Değer",float_val)
print(type(float_val))

#string
string_val = "Merhaba"
print("\nString Değer",string_val)
print(type(string_val))

#boolean
bool_val = True
print("\nBoolean Değer",bool_val)
print(type(bool_val))
# Out:
# Merhaba Dünya
# İnteger Değer 10
# <class 'int'>
#
# Float Değer 10.5
# <class 'float'>
#
# String Değer Merhaba
# <class 'str'>
#
# Boolean Değer True
# <class 'bool'>
